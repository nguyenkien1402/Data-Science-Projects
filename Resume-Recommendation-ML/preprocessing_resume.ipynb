# %% [markdown]
# #### Author: Trung Kien Nguyen
#
# Created_Date : 14/08/2018
#
# Modified_Date: 02/09/2018
#
#
# Environment: Python 3.6.0 and Anaconda 5.2.0 (64-bit)
#
# Version: 2.0
#
# Libraries used:
# * nltk 3.2.3
# * pdfminer 20160614
# * pandas (for data frame, included in Anaconda Python 3.6)
# * re (for regular expression, included in Anaconda Python 3.6)
# * numpy (for numpy array, included in Anconda
#
#
# ## 1. Introduction
# This project comprises 250 CVs with the aim is to build sparse representations for the resumes, which included word tokenization, vocabulary generation and the generation of sparse representations. There a file named of each CV following 'resume_(*number*).txt' with the given number from given file "resume_dataset.txt"
#
# 1. File output named resume_vocab.txt which contains bigrams and unigrams tokens in the following format: token_string:integer_index. Words in the vocabulary must be sorted in order
#
# 2. File output named resume_countVec.txt which contains all the "selected" resumes in the data-set. Each line in the text file contains the sparse representations of one of the resumes in the data-set in the following format:
#
#     file_name,token_index:count,token_index:count
#
#
# More details for each task will be given in the following sections.

# %% [markdown]
# ## 2. Import Libraries

# %%
import io
from io import StringIO
import pandas as pd
import numpy as np
import nltk
import re
from nltk.tokenize import RegexpTokenizer
from nltk.stem.porter import PorterStemmer
from nltk.collocations import *
from sklearn.feature_extraction.text import TfidfVectorizer,CountVectorizer

# For loading pdf file if needed
from pdfminer.pdfinterp import PDFResourceManager, PDFPageInterpreter
from pdfminer.converter import TextConverter
from pdfminer.layout import LAParams
from pdfminer.pdfpage import PDFPage

# %% [markdown]
# ## 3. Pre-processing Data

# %% [markdown]
# *cv_list* is a list contain all the number which relevant to the CVs number

# %%
cv_list = [i for i in range(1000)]

# %%
# a function to get the path name for each particular cv 
def get_path_resume(number):
    """
    This function to get path name for a cv
    :param 
        number: the CV's number
    :result: path name of cv
    """
    return "./resumeTxt/resume_("+str(number)+ ").txt"


def read_cv_txt(path):
    """
    This function to get content of specific resume from given path
    :param 
        path: the path to the specific resume
    :result: the list of each line from the content of resume
    """
    with open(path,'rb') as f:
        data = f.readlines()
    return data

# %% [markdown]
# This section to deal with the first requirement of task 2, which construct vocabulary from all the given CVs.
#
# All the given CVs are in "*.txt" format. In order to get information from txt file, we will use a function read_cv_txt(), which is defined above.
#
# If you want to read ".pdf" format, we will use the library, called *pdfminer*. Reading a pdf file is not necessary in this task, however, I will leave a function, called "convert_pdf_to_txt" for the purpose of references.
#
# Note: there are two version of *pdfminer*. Please select the right package *pdfminer* for your version of Python
#
# For python 2:
# ```shell
#         pip install pdfminer
# ```
# For python 3:
# ```shell
#         pip install pdfminer.six
# ```
#
#
# In the following script, we defined a function called *convert_pdf_to_txt*. From the name of function tell us pretty much everything what that function doing. It will convert a pdf format file to string

# %%
def convert_pdf_to_txt(path):
    rsrcmgr = PDFResourceManager()
    retstr = io.StringIO()
    codec = 'utf-8'
    laparams = LAParams()
    device = TextConverter(rsrcmgr, retstr, codec=codec, laparams=laparams)
    fp = open(path, 'rb')
    interpreter = PDFPageInterpreter(rsrcmgr, device)
    password = ""
    maxpages = 0
    caching = True
    pagenos = set()

    for page in PDFPage.get_pages(fp, pagenos, maxpages=maxpages,
                                  password=password,
                                  caching=caching,
                                  check_extractable=True):
        interpreter.process_page(page)

    text = retstr.getvalue()

    fp.close()
    device.close()
    retstr.close()
    return text

# %% [markdown]
# Now, let's read a specific resume to see the contents.

# %%
sample = read_cv_txt(get_path_resume(1))
sample
# Out:
# [b'Curriculum Vitae \r\n',
#  b'\r\n',
#  b'V. Gowribalan  MCSI \r\n',
#  b'  FCMA, CPA (Aust.), CGMA, BSc  (Hons.)  \r\n',
#  b'\r\n',
#  b' \r\n',
#  b'Investment Manager with an  established  investment  track-record  across  the GCC  region  spanning  \r\n',
#  b'listed equities, sukuks and debt securities.  Honed expertise of 14 years in portfolio management and \r\n',
#  b'investment analysis. Experience  includes  establishing and  leading  the Asset Management Division \r\n',
#  b'(AMD) of Ahli Bank SAOG; launching of mutual fund, structuring of wealth management products, \r\n',
#  b'strategizing acquisitions, handling initial public offerings (IPOs) and raising investment funds across \r\n',
#  b'asset-classes and risk-thresholds.  \r\n',
#  b' \r\n',
#  b'Credentials  include a First Class Honours Degree  in Applied Accounting   (BSc. Hons.), Member of \r\n',
#  b'the Chartered Institute of Securities and Investment \xe2\x80\x93 U.K. (MCSI), Fellow of the Chartered Institute \r\n',
#  b'of  Management  Accountants  \xe2\x80\x93  U.K.  (FCMA),  Certified  Practising  Accountant  (CPA  Aust.)  and \r\n',
#  b'Chartered Global Management Accountant \xe2\x80\x93 U.S.A. (CGMA). \r\n',
#  b' \r\n',
#  b'Average returns generated amounts to 12.5% (annual average) over the past 9 years, across the GCC \r\n',
#  b'listed equities and exceeding 4.5% within the fixed income asset class.  \r\n',
#  b' \r\n',
#  b' \r\n',
#  b' \r\n',
#  b' \r\n',
#  b' \r\n',
#  b'\r\n',
#  b'PROFESSIONAL EXPERIENCE \xef\x82\xbb 14 YEARS \r\n',
#  b'\r\n',
#  b' \r\n',
#  b'\r\n',
#  b' \r\n',
#  b'\r\n',
#  b' \r\n',
#  b'\r\n',
#  b' \r\n',
#  b'\r\n',
#  b' \r\n',
#  b'\r\n',
#  b' \r\n',
#  b'\r\n',
#  b' \r\n',
#  b'\r\n',
#  b' \r\n',
#  b'\r\n',
#  b'    (3\xe2\x85\x93 Yrs. / Oct.`12 \xe2\x80\x93 Feb.\xe2\x80\x9916) \r\n',
#  b'\r\n',
#  b' \r\n',
#  b'Ahli Bank SAOG \r\n',
#  b'(www.ahlibank.om)  \r\n',
#  b' \r\n',
#  b'Head of Asset Management \r\n',
#  b'Reported  to CEO;  founding  employee of  the  division,  tasked with  establishing  the  business  vertical  for  the \r\n',
#  b'banking franchise. \r\n',
#  b' \r\n',
#  b'Achievements: Built a client profile spanning the GCC region, encompassing; Pension Funds, Banks, Insurance \r\n',
#  b'Companies, Takaful operators, Large Corporates, Family offices and HNI/Individual investors. \r\n',
#  b' \r\n',
#  b'Investment  Management:  GCC/MENA  focused  \xe2\x80\x93  capital  market  investments  via  Mutual  Fund  and \r\n',
#  b'Discretionary Portfolio Management (DPM) service offerings tailored to suit varied risk tolerances. I  led the \r\n',
#  b'investment  managers  with  oversight  on  asset  allocation,  security  universe  selection  and  ma rket  risk \r\n',
#  b'management. \r\n',
#  b'\xe2\x80\xa2 \r\n',
#  b'First in the market with exclusive DPM service offering, focusing on Income/Debt securities, \r\n',
#  b'Grew AUM from inception up to USD 340 Mn. \xe2\x80\x93 within 3 years, \r\n',
#  b'\xe2\x80\xa2 \r\n',
#  b'\xe2\x80\xa2 \r\n',
#  b'AUM demography \xe2\x80\x93 61% fixed income / debt securities, remainder GCC equities. \r\n',
#  b'\r\n',
#  b' \r\n',
#  b'Investment advisory & placement: Oman Sovereign Sukuk \xe2\x80\x93 investment advisory - (USD 654 Mn.), 3 Power \r\n',
#  b'Company IPOs \xe2\x80\x93 acted as collecting agent (USD 305 Mn.), Omantel 2nd IPO\xe2\x80\x93 acted as collecting agent (USD \r\n',
#  b'248  Mn.),  Islamic  Bank  and  Takaful  operator  IPO  collecting  agent  (USD  129  Mn.),  Oman\xe2\x80\x99s  first  Sharia \r\n',
#  b'complaint MENA focused fund \xe2\x80\x93 issue manager, fund manager & collecting agent. \r\n',
#  b' \r\n',
#  b'Wealth Management - Product Development: \r\n',
#  b'\xef\x82\xb7 Yield Enhancer Series (YES) Notes  - income enhancing, asset backed notes of fixed term and return \r\n',
#  b'\xef\x82\xb7 ahli-annuities - self-directed wealth management and retirement planning solutions \r\n',
#  b' \r\n',
#  b'\xef\x82\xb7 Gulf Retirement and Investment Plan (GRIP) \xe2\x80\x93 holistic services platform targeting self -directed retirement \r\n',
#  b'planning and wealth management solutions \r\n',
#  b' \r\n',
#  b'Key acquisitions: \r\n',
#  b'\xef\x82\xb7 Gulf Mushroom Products Co. (GMPI) 22.5% stake  \r\n',
#  b'\xef\x82\xb7 Majan Glass (MGCI) 3.5% stake \r\n',
#  b'\r\n',
#  b'\xef\x82\xb7 Sweets of Oman (OSCI) 7.6% stake   \r\n',
#  b'\r\n',
#  b' \r\n',
#  b'\r\n',
#  b' \r\n',
#  b'\r\n',
#  b'e mail : vgowribalan@gmail.com     :     vgowribalan@live.com                  Mobile : (+971) 50 246 0800 \r\n',
#  b'\r\n',
#  b'\x0cCurriculum Vitae \r\n',
#  b'\r\n',
#  b' \r\n',
#  b'\r\n',
#  b' \r\n',
#  b'\r\n',
#  b' \r\n',
#  b'\r\n',
#  b' \r\n',
#  b'\r\n',
#  b' \r\n',
#  b'\r\n',
#  b' \r\n',
#  b'\r\n',
#  b' \r\n',
#  b'\r\n',
#  b'           (1 Yr. / Apr\xe2\x80\x9907 \xe2\x80\x93 Jun\xe2\x80\x9908) \r\n',
#  b'\r\n',
#  b'    (4\xc2\xbc Yrs. / Jun.\xe2\x80\x9908 \xe2\x80\x93 Sep.\xe2\x80\x9912) \r\n',
#  b'\r\n',
#  b' \r\n',
#  b' \r\n',
#  b' \r\n',
#  b'Oman National Investment Corporation (ONIC) Holding SAOG \r\n',
#  b'(www.onicholding.com) \r\n',
#  b' \r\n',
#  b' \r\n',
#  b'Portfolio Manager \r\n',
#  b' \r\n',
#  b'Reported to the Chief Executive Officer, as a member of the Management Investment Committee, responsible \r\n',
#  b'for  formulating  overall  investment  and  portfolio  management  strategy.  The  portfolios  under  purview \r\n',
#  b'included the proprietary portfolio and the Insurance subsidiary portfolio (Insurance Policy holders funds are \r\n',
#  b'managed in-accordance with the Capital Market Authority stipulated investment guidelines). \r\n',
#  b' \r\n',
#  b'Oversight  over  a  portfolio  of  USD  250Mn,  which  consisted  of  market  coverage  spanning  the  GCC  region \r\n',
#  b'(Equities and Fixed Income), Strategic Holdings across financial services sector and select Global ETFs. \r\n',
#  b' \r\n',
#  b'Returns earned, averaged 18% p.a. over 4 years and \xe2\x80\x98alpha\xe2\x80\x99 (6% average) over the years. \r\n',
#  b' \r\n',
#  b' \r\n',
#  b'The Financial Corporation Co. SAOG  \r\n',
#  b'(FINCORP) (www.fincorp.org) \r\n',
#  b' \r\n',
#  b'Assistant Vice President / AVP \r\n',
#  b' \r\n',
#  b'Reported  to  the  EVP,  formulated  trading &  portfolio  management  strategies  for  discretionary  and  mutual \r\n',
#  b'fund assets under management. \r\n',
#  b' \r\n',
#  b'Achievements: Total portfolio under management - USD 220Mn (RO. 85Mn.) / Return (70% p.a.) - Mutual funds \r\n',
#  b'under management recorded exceptional performance, exhibiting low-volatility, and impressive risk adjusted \r\n',
#  b'returns notching alpha (\xce\xb1) in excess of 7% (Best Performing funds \xe2\x80\x93 2007) \r\n',
#  b'\xef\x82\xb7   Generated  realised gains  in  excess of  $  2.8Mn.  for  the proprietary trading portfolio  (RO.  1.1Mn.) / Return \r\n',
#  b'(70% p.a.) \r\n',
#  b' \r\n',
#  b'Since appointment initiated equity research reports in the following segments: \r\n',
#  b'Banking - Oman International Bank SAOG (OIBB)  Cement - Oman Cement Co. SAOG (OCOI)  \r\n',
#  b'Steel - Al Jazeera Steel Products SAOG (ATMI) \r\n',
#  b'Telecom - Oman Telecommunication Co. SAOG (OTEL) \r\n',
#  b'Worked as lead analyst for an IPO of a large contracting and engineering company, which emerged the \r\n',
#  b'largest IPO in the history of the capital market of the Sultanate as at Dec. 2007 (GECS). \r\n',
#  b' \r\n',
#  b' \r\n',
#  b'MGH Associates Ltd. (www.mghglobal.com) \r\n',
#  b' \r\n',
#  b'Chief Trader \r\n',
#  b' \r\n',
#  b' \r\n',
#  b'Achievements:  Since  appointment  achieved  an  ROI  of  63%  p.a.     and  increased  total  portfolio  under \r\n',
#  b'management to $ 15Mn. An increase of 73%, with returns of 45% p.a. \r\n',
#  b' \r\n',
#  b' \r\n',
#  b'HNB Securities Ltd. (www.hnb.lk / www.hnbsl.lk)  \r\n',
#  b' \r\n',
#  b' \r\n',
#  b'Assistant Manager - Trading & Strategy \r\n',
#  b' \r\n',
#  b'Reported to the CEO, responsible for formulating the respective trading strategies for all markets in operation: \r\n',
#  b'Equity Trading, Bond Trading and Money Market Trading. \r\n',
#  b' \r\n',
#  b'\xef\x82\xb7 Total Portfolio under management US$ 100 Mn. / Return (48% p.a.) \xef\x82\xb7 Total Trading Profits earned $ 6.37Mn. \r\n',
#  b'\xef\x82\xb7 ROI of 52% p.a. average maintained for the period(s). \r\n',
#  b' \r\n',
#  b' \r\n',
#  b'Ernst & Young (www.ey.com) \r\n',
#  b' \r\n',
#  b'\r\n',
#  b'         (1 Yr. 3 Mths. / Jan`06 \xe2\x80\x93 Mar`07) \r\n',
#  b'\r\n',
#  b'     (3 Yrs. / Nov`02 \xe2\x80\x93 Nov`05) \r\n',
#  b'\r\n',
#  b'Financial Assurance Executive \r\n',
#  b'\r\n',
#  b'   (8 Mths. / Mar`02 \xe2\x80\x93 Nov`02) \r\n',
#  b'\r\n',
#  b' \r\n',
#  b'\r\n',
#  b' \r\n',
#  b'\r\n',
#  b' \r\n',
#  b'\r\n',
#  b' \r\n',
#  b' \r\n',
#  b'\r\n',
#  b' \r\n',
#  b'\r\n',
#  b' \r\n',
#  b' \r\n',
#  b'\r\n',
#  b' \r\n',
#  b'\r\n',
#  b' \r\n',
#  b' \r\n',
#  b'\r\n',
#  b' \r\n',
#  b'\r\n',
#  b' \r\n',
#  b'\r\n',
#  b'e mail : vgowribalan@gmail.com     :     vgowribalan@live.com                  Mobile : (+971) 50 246 0800 \r\n',
#  b'\r\n',
#  b'\x0c \r\n',
#  b'PROFESSIONAL EXPERIENCE \xef\x82\xbb 14 YEARS \r\n',
#  b' \r\n',
#  b'\r\n',
#  b'ROLE \r\n',
#  b'\r\n',
#  b'ORGANISATION \r\n',
#  b'\r\n',
#  b'TENURE \r\n',
#  b'\r\n',
#  b'AVERAGE \r\n',
#  b'RETURN \r\n',
#  b'\r\n',
#  b'Curriculum Vitae \r\n',
#  b'\r\n',
#  b'Head of Asset Management \r\n',
#  b'\r\n',
#  b'Ahli Bank SAOG \r\n',
#  b'\r\n',
#  b'Portfolio Manager \r\n',
#  b'\r\n',
#  b'Assistant Vice President / AVP \r\n',
#  b'\r\n',
#  b'Oman National Inve stment Corporation  \r\n',
#  b'ONIC Holding SAOG \r\n',
#  b'\r\n',
#  b'The Financ ial Corporation Co. SAOG  \r\n',
#  b'FINCORP \r\n',
#  b'\r\n',
#  b'Chief Trader \r\n',
#  b'\r\n',
#  b'MGH Associates Ltd. \r\n',
#  b'\r\n',
#  b'Trading & Strategy \r\n',
#  b'Assistant Manager \r\n',
#  b'\r\n',
#  b'HNB Securities Ltd. \r\n',
#  b'Hatton Nat ional Bank (HNB)  \r\n',
#  b'\r\n',
#  b'Financial Assurance Executive \r\n',
#  b'\r\n',
#  b'Ernst & Young \r\n',
#  b'\r\n',
#  b' \r\n',
#  b'\r\n',
#  b' \r\n',
#  b' \r\n',
#  b' \r\n',
#  b'\r\n',
#  b'8% p.a. \r\n',
#  b'\r\n',
#  b'18% p.a. \r\n',
#  b'\r\n',
#  b'3\xe2\x85\x93 Yrs. / \r\n',
#  b'1st Oct.`12 \xe2\x80\x93 15th Feb.`16 \r\n',
#  b'4\xc2\xbc Yrs. / \r\n',
#  b'28th Jun.\xe2\x80\x9908 \xe2\x80\x93 30th Sep.\xe2\x80\x9912 \r\n',
#  b'1 Yr. / \r\n',
#  b'28th Apr\xe2\x80\x9907 \xe2\x80\x93 8th Jun\xe2\x80\x9908 \r\n',
#  b'1 Yr. 3 Mths. / \r\n',
#  b'1st Jan`06 \xe2\x80\x93 31st Mar`07 \r\n',
#  b'3 Yrs. / \r\n',
#  b'23rd Nov`02 \xe2\x80\x93 30th Nov`05)  52% p.a. \r\n',
#  b'8 Mths. / \r\n',
#  b'1st Mar`02 \xe2\x80\x93 6th Nov`02 \r\n',
#  b'\r\n',
#  b'70% p.a. \r\n',
#  b'\r\n',
#  b'45% p.a. \r\n',
#  b'\r\n',
#  b'n/a \r\n',
#  b'\r\n',
#  b'ACADEMIC & PROFESSIONAL CREDENTIALS \r\n',
#  b'\r\n',
#  b' \r\n',
#  b'Academic Qualifications: \r\n',
#  b' \r\n',
#  b'\r\n',
#  b'\xef\x82\xb7  BSc (Hons.) \xe2\x80\x93First Class \xe2\x80\x93 Applied Accounting (University of Oxford Brookes, Oxford, U.K. ) \r\n',
#  b'\r\n',
#  b' \r\n',
#  b'Professional Qualifications: \r\n',
#  b' \r\n',
#  b'\r\n',
#  b' \r\n',
#  b'\r\n',
#  b'\xef\x82\xb7  MCSI / Member of the Chartered Institute of Securities and Investment  (Membership No . 134821) \r\n',
#  b'\xef\x82\xb7  FCMA / Fellow of the Chartered Institute of Management Accountants  \xe2\x80\x93 U.K. (Registration No. 1-HNSP) \r\n',
#  b'\xef\x82\xb7  CPA / Certified Practising Accountant \xe2\x80\x93 Australia (Membership No. 9582697) \r\n',
#  b'\xef\x82\xb7  CGMA /Chartered Global Management Accountant \r\n',
#  b'\r\n',
#  b' \r\n',
#  b'Certifications: \r\n',
#  b' \r\n',
#  b'\r\n',
#  b'International Certificate in Wealth & Investment Management (CISI) \r\n',
#  b'\xef\x82\xb7 \r\n',
#  b'\xef\x82\xb7  Risk in Financial Services (CISI) \r\n',
#  b'\xef\x82\xb7  Operational Risk (CISI) \r\n',
#  b'\xef\x82\xb7  ACI (The Financ ial Market Assoc iation) Certified Dealer \r\n',
#  b'\xef\x82\xb7  Emotional Intelligence (CBFS) \r\n',
#  b'\xef\x82\xb7  Colombo Stock Exchange (CSE) Certified  Investment Advisor, Derivatives Trader & Sponsor \r\n',
#  b'\xef\x82\xb7  Euro Money Certified Professional \xe2\x80\x93 Capital Market & Bond Mathematics \r\n',
#  b'\xef\x82\xb7  Central Bank of Sri Lanka Certified Finance Professional  \r\n',
#  b'\xef\x82\xb7  Obtained a Merit Pass (A) from the Vinod Kothari School of Securitisation  \r\n',
#  b'\r\n',
#  b' \r\n',
#  b'Professional & Personal development: \r\n',
#  b' \r\n',
#  b'\r\n',
#  b'\xef\x82\xb7  Platform competence \xe2\x80\x93 Reuters Eikon & Zawya  \r\n',
#  b'\xef\x82\xb7  Technical Analysis \xe2\x80\x93 Reuters / Smartline Training Institute (14 day resident course) \r\n',
#  b'\xef\x82\xb7  Financial system stability and framework \xe2\x80\x93 Central Bank of Sri Lanka \r\n',
#  b'\xef\x82\xb7  Capital Market Development \xe2\x80\x93 SEC/Securities and Exchange Commission, Sri Lanka \r\n',
#  b'Securitisation - SEC/Securities and Exchange Commission, Sri Lanka \r\n',
#  b'\xef\x82\xb7 \r\n',
#  b'\r\n',
#  b' \r\n',
#  b'\r\n',
#  b' \r\n',
#  b' \r\n',
#  b' \r\n',
#  b'\r\n',
#  b' \r\n',
#  b'\r\n',
#  b'Date of Birth \r\n',
#  b'\r\n',
#  b': \r\n',
#  b'\r\n',
#  b'4th January 1981  \r\n',
#  b'\r\n',
#  b' \r\n',
#  b'\r\n',
#  b'Resident \r\n',
#  b'\r\n',
#  b': \r\n',
#  b'\r\n',
#  b'Dubai, UAE \r\n',
#  b'\r\n',
#  b' \r\n',
#  b'PERSONAL DETAILS \r\n',
#  b'\r\n',
#  b'e mail : vgowribalan@gmail.com     :     vgowribalan@live.com                  Mobile : (+971) 50 246 0800 \r\n',
#  b'\r\n',
#  b'\x0c']

# %% [raw]
# Overview quickly to the result above, we see that `\n` happend several time. The `\n` notation refer to the new line. We also notice that for every element of the list, the contents are always start with `b`. The reason because in the function read_cv_txt, we put the reading mode was 'rb' which was read byte data.
#
# We are going to fix this issuer in the following script.

# %% [markdown]
# ----------
#
#
# Now, when we have each particular line for entire text format of CV, we are going to normalized each line by following rule: Each word must be normalized to lowercase except the capital words appeared in the middle of a sentence/line.
#
# For example:
#
# "Manager" appears in the middle  will be retain.
#
# "MANAGER"  appears in the middle will be retain.
#
# but if "Manager" or "MANAGER" appears at the beginning of the sentence will be transform to "manager"
#
# The function *data_byte_to_str* use to fix data-byte issue.
#
# The function *normalized_line* use to normalized each line of content of resume by following the rules above.
#
# The function *normalized_lower_case* use to normalized all the contents of resume by calling the function *normalized_line* and then concatenate all the content together.

# %%
# Fix the issue of read data-byte
def data_byte_to_str(cv_lines_arr):
    return [str(line.strip(),'utf-8') for line in cv_lines_arr if line.strip() != b'']


# Normalize each line of content of resume
def normalized_line(line,is_dot_before=False):
    """
    This function use to normalize each line of content of resume
    :param
        line: each single line of content of resume
        is_dot_before: a variable to check whether the previous line end with dot or not. If previous line end with dot,
                       we will normalized the first word of sentence, otherwise, retain it.
    :result
        return a string of line
    """
    
    # if the previous line end with dot
    if is_dot_before == True:
        # seperate the line by dot function if the line invole more than two sentence
        lines = line.split(". ")
        for i in range(0,len(lines)):
            if len(lines[i])>2:
                txt = lines[i].split(" ")
                for j in range(0,len(txt)):
                    if txt[j].isalpha():
                        txt[j] = txt[j].lower()
                        break
                lines[i] = " ".join(txt)
                
    # if the previous line is not end with dot            
    else:
        lines = line.split(". ")
        for i in range(1,len(lines)):
            if len(lines[i])>2:
                txt = lines[i].split(" ")
                for j in range(0,len(txt)):
                    if txt[j].isalpha():
                        txt[j] = txt[j].lower()
                        break
                lines[i] = " ".join(txt)
    return ". ".join(lines)


# Normalize content of resume
def normalized_lower_case(cv_lines_arr):
    """
    This function use to normalize the content of resume
    :param 
        cv_lines: the list of line of the resume content
    :result
        return a string of resume content
    """
    cv_lines_arr = data_byte_to_str(cv_lines_arr)
    cv_lines_arr[0] = normalized_line(cv_lines_arr[0],is_dot_before=True)  
    
    for i in range(1,len(cv_lines_arr)):
        if cv_lines_arr[i-1].endswith(".") or cv_lines_arr[i-1].endswith(":"):
            cv_lines_arr[i] = normalized_line(cv_lines_arr[i],is_dot_before=True)
        else:
            cv_lines_arr[i] = normalized_line(cv_lines_arr[i])
    return " ".join(cv_lines_arr)
    
sample_normalize = normalized_lower_case(sample)
sample_normalize
# Out:
# 'curriculum Vitae V. gowribalan  MCSI FCMA, CPA (Aust.), CGMA, BSc  (Hons.) Investment Manager with an  established  investment  track-record  across  the GCC  region  spanning listed equities, sukuks and debt securities.  honed expertise of 14 years in portfolio management and investment analysis. experience  includes  establishing and  leading  the Asset Management Division (AMD) of Ahli Bank SAOG; launching of mutual fund, structuring of wealth management products, strategizing acquisitions, handling initial public offerings (IPOs) and raising investment funds across asset-classes and risk-thresholds. credentials  include a First Class Honours Degree  in Applied Accounting   (BSc. Hons.), member of the Chartered Institute of Securities and Investment – U.K. (MCSI), fellow of the Chartered Institute of  Management  Accountants  –  U.K.  (FCMA),  certified  Practising  Accountant  (CPA  Aust.)  and Chartered Global Management Accountant – U.S.A. (CGMA). average returns generated amounts to 12.5% (annual average) over the past 9 years, across the GCC listed equities and exceeding 4.5% within the fixed income asset class. professional EXPERIENCE \uf0bb 14 YEARS (3⅓ Yrs. / Oct.`12 – Feb.’16) Ahli Bank SAOG (www.ahlibank.om) Head of Asset Management Reported  to CEO;  founding  employee of  the  division,  tasked with  establishing  the  business  vertical  for  the banking franchise. Achievements: built a client profile spanning the GCC region, encompassing; Pension Funds, Banks, Insurance Companies, Takaful operators, Large Corporates, Family offices and HNI/Individual investors. investment  Management:  GCC/MENA  focused  –  capital  market  investments  via  Mutual  Fund  and Discretionary Portfolio Management (DPM) service offerings tailored to suit varied risk tolerances. i  led the investment  managers  with  oversight  on  asset  allocation,  security  universe  selection  and  ma rket  risk management. • First in the market with exclusive DPM service offering, focusing on Income/Debt securities, Grew AUM from inception up to USD 340 Mn. – within 3 years, • • AUM demography – 61% fixed income / debt securities, remainder GCC equities. investment advisory & placement: Oman Sovereign Sukuk – investment advisory - (USD 654 Mn.), 3 Power Company IPOs – acted as collecting agent (USD 305 Mn.), Omantel 2nd IPO– acted as collecting agent (USD 248  Mn.),  Islamic  Bank  and  Takaful  operator  IPO  collecting  agent  (USD  129  Mn.),  Oman’s  first  Sharia complaint MENA focused fund – issue manager, fund manager & collecting agent. wealth Management - Product Development: \uf0b7 yield Enhancer Series (YES) Notes  - income enhancing, asset backed notes of fixed term and return \uf0b7 ahli-annuities - self-directed wealth management and retirement planning solutions \uf0b7 Gulf Retirement and Investment Plan (GRIP) – holistic services platform targeting self -directed retirement planning and wealth management solutions Key acquisitions: \uf0b7 gulf Mushroom Products Co. (GMPI) 22.5% stake \uf0b7 Majan Glass (MGCI) 3.5% stake \uf0b7 Sweets of Oman (OSCI) 7.6% stake e mail : vgowribalan@gmail.com     :     vgowribalan@live.com                  Mobile : (+971) 50 246 0800 Curriculum Vitae (1 Yr. / Apr’07 – Jun’08) (4¼ Yrs. / Jun.’08 – Sep.’12) Oman National Investment Corporation (ONIC) Holding SAOG (www.onicholding.com) Portfolio Manager Reported to the Chief Executive Officer, as a member of the Management Investment Committee, responsible for  formulating  overall  investment  and  portfolio  management  strategy.  the  portfolios  under  purview included the proprietary portfolio and the Insurance subsidiary portfolio (Insurance Policy holders funds are managed in-accordance with the Capital Market Authority stipulated investment guidelines). oversight  over  a  portfolio  of  USD  250Mn,  which  consisted  of  market  coverage  spanning  the  GCC  region (Equities and Fixed Income), Strategic Holdings across financial services s ...

# %% [markdown]
# ------------
# In the next part, we are going to extract tokens from the text by using regular expression:
# ```python
#     from nltk.tokenize import RegexpTokenizer
#     pattern = "\w+(?:[-']\w+)?"
#     tokenizer = RegexpTokenizer(pattern)
# ```
#
# Before doing that, we need to transfrom the list of line from to string. Again, we put the script of extracting tokens to a function, called *get_tokens*

# %%
def get_tokens(resume_content):
    """
    This function use to get token from normalized text 
    :param 
        cv_lines: a list of line that have normalized
    :result
        the string of all tokens
    """
    pattern = r"\w+(?:[-']\w+)?"
    tokenizer = RegexpTokenizer(pattern)
    cv_tokens = tokenizer.tokenize(resume_content)
    cv_text = " ".join(cv_tokens)
    return cv_text

cv_text = get_tokens(sample_normalize)
cv_text
# Out:
# 'curriculum Vitae V gowribalan MCSI FCMA CPA Aust CGMA BSc Hons Investment Manager with an established investment track-record across the GCC region spanning listed equities sukuks and debt securities honed expertise of 14 years in portfolio management and investment analysis experience includes establishing and leading the Asset Management Division AMD of Ahli Bank SAOG launching of mutual fund structuring of wealth management products strategizing acquisitions handling initial public offerings IPOs and raising investment funds across asset-classes and risk-thresholds credentials include a First Class Honours Degree in Applied Accounting BSc Hons member of the Chartered Institute of Securities and Investment U K MCSI fellow of the Chartered Institute of Management Accountants U K FCMA certified Practising Accountant CPA Aust and Chartered Global Management Accountant U S A CGMA average returns generated amounts to 12 5 annual average over the past 9 years across the GCC listed equities and exceeding 4 5 within the fixed income asset class professional EXPERIENCE 14 YEARS 3⅓ Yrs Oct 12 Feb 16 Ahli Bank SAOG www ahlibank om Head of Asset Management Reported to CEO founding employee of the division tasked with establishing the business vertical for the banking franchise Achievements built a client profile spanning the GCC region encompassing Pension Funds Banks Insurance Companies Takaful operators Large Corporates Family offices and HNI Individual investors investment Management GCC MENA focused capital market investments via Mutual Fund and Discretionary Portfolio Management DPM service offerings tailored to suit varied risk tolerances i led the investment managers with oversight on asset allocation security universe selection and ma rket risk management First in the market with exclusive DPM service offering focusing on Income Debt securities Grew AUM from inception up to USD 340 Mn within 3 years AUM demography 61 fixed income debt securities remainder GCC equities investment advisory placement Oman Sovereign Sukuk investment advisory USD 654 Mn 3 Power Company IPOs acted as collecting agent USD 305 Mn Omantel 2nd IPO acted as collecting agent USD 248 Mn Islamic Bank and Takaful operator IPO collecting agent USD 129 Mn Oman s first Sharia complaint MENA focused fund issue manager fund manager collecting agent wealth Management Product Development yield Enhancer Series YES Notes income enhancing asset backed notes of fixed term and return ahli-annuities self-directed wealth management and retirement planning solutions Gulf Retirement and Investment Plan GRIP holistic services platform targeting self directed retirement planning and wealth management solutions Key acquisitions gulf Mushroom Products Co GMPI 22 5 stake Majan Glass MGCI 3 5 stake Sweets of Oman OSCI 7 6 stake e mail vgowribalan gmail com vgowribalan live com Mobile 971 50 246 0800 Curriculum Vitae 1 Yr Apr 07 Jun 08 4¼ Yrs Jun 08 Sep 12 Oman National Investment Corporation ONIC Holding SAOG www onicholding com Portfolio Manager Reported to the Chief Executive Officer as a member of the Management Investment Committee responsible for formulating overall investment and portfolio management strategy the portfolios under purview included the proprietary portfolio and the Insurance subsidiary portfolio Insurance Policy holders funds are managed in-accordance with the Capital Market Authority stipulated investment guidelines oversight over a portfolio of USD 250Mn which consisted of market coverage spanning the GCC region Equities and Fixed Income Strategic Holdings across financial services sector and select Global ETFs returns earned averaged 18 p a over 4 years and alpha 6 average over the years the Financial Corporation Co saog FINCORP www fincorp org Assistant Vice President AVP Reported to the EVP formulated trading portfolio management strategies for discretionary and mutual fund assets under management Achievements total portfolio under management USD 220Mn RO ...

# %% [markdown]
# -------
#
# Next, we are going to remove all the token has length less than 3.
#
# Following is regular expression:
#
# ``` python
#     import re
#     line = re.sub(r'\b\w{1,3}\b','', line)
# ```

# %%
def removal_token_length(cv_text):
    """
    This function use to remove all the token has length less than 3
    :param
        cv_text: a string of cv
    :result
        a string of token
    """
    cv_text = re.sub(r'\b\[a-zA-Z0-9-_]\b','',cv_text)
    return cv_text

cv_text = removal_token_length(cv_text)
cv_text
# Out:
# 'curriculum Vitae V gowribalan MCSI FCMA CPA Aust CGMA BSc Hons Investment Manager with an established investment track-record across the GCC region spanning listed equities sukuks and debt securities honed expertise of 14 years in portfolio management and investment analysis experience includes establishing and leading the Asset Management Division AMD of Ahli Bank SAOG launching of mutual fund structuring of wealth management products strategizing acquisitions handling initial public offerings IPOs and raising investment funds across asset-classes and risk-thresholds credentials include a First Class Honours Degree in Applied Accounting BSc Hons member of the Chartered Institute of Securities and Investment U K MCSI fellow of the Chartered Institute of Management Accountants U K FCMA certified Practising Accountant CPA Aust and Chartered Global Management Accountant U S A CGMA average returns generated amounts to 12 5 annual average over the past 9 years across the GCC listed equities and exceeding 4 5 within the fixed income asset class professional EXPERIENCE 14 YEARS 3⅓ Yrs Oct 12 Feb 16 Ahli Bank SAOG www ahlibank om Head of Asset Management Reported to CEO founding employee of the division tasked with establishing the business vertical for the banking franchise Achievements built a client profile spanning the GCC region encompassing Pension Funds Banks Insurance Companies Takaful operators Large Corporates Family offices and HNI Individual investors investment Management GCC MENA focused capital market investments via Mutual Fund and Discretionary Portfolio Management DPM service offerings tailored to suit varied risk tolerances i led the investment managers with oversight on asset allocation security universe selection and ma rket risk management First in the market with exclusive DPM service offering focusing on Income Debt securities Grew AUM from inception up to USD 340 Mn within 3 years AUM demography 61 fixed income debt securities remainder GCC equities investment advisory placement Oman Sovereign Sukuk investment advisory USD 654 Mn 3 Power Company IPOs acted as collecting agent USD 305 Mn Omantel 2nd IPO acted as collecting agent USD 248 Mn Islamic Bank and Takaful operator IPO collecting agent USD 129 Mn Oman s first Sharia complaint MENA focused fund issue manager fund manager collecting agent wealth Management Product Development yield Enhancer Series YES Notes income enhancing asset backed notes of fixed term and return ahli-annuities self-directed wealth management and retirement planning solutions Gulf Retirement and Investment Plan GRIP holistic services platform targeting self directed retirement planning and wealth management solutions Key acquisitions gulf Mushroom Products Co GMPI 22 5 stake Majan Glass MGCI 3 5 stake Sweets of Oman OSCI 7 6 stake e mail vgowribalan gmail com vgowribalan live com Mobile 971 50 246 0800 Curriculum Vitae 1 Yr Apr 07 Jun 08 4¼ Yrs Jun 08 Sep 12 Oman National Investment Corporation ONIC Holding SAOG www onicholding com Portfolio Manager Reported to the Chief Executive Officer as a member of the Management Investment Committee responsible for formulating overall investment and portfolio management strategy the portfolios under purview included the proprietary portfolio and the Insurance subsidiary portfolio Insurance Policy holders funds are managed in-accordance with the Capital Market Authority stipulated investment guidelines oversight over a portfolio of USD 250Mn which consisted of market coverage spanning the GCC region Equities and Fixed Income Strategic Holdings across financial services sector and select Global ETFs returns earned averaged 18 p a over 4 years and alpha 6 average over the years the Financial Corporation Co saog FINCORP www fincorp org Assistant Vice President AVP Reported to the EVP formulated trading portfolio management strategies for discretionary and mutual fund assets under management Achievements total portfolio under management USD 220Mn RO ...

# %% [markdown]
# All the token which has length less than 3 have been removed, however we see that the space between the word are not normal.
#
# We will remove more than one white-space between words, following is regular expression
# ```python
#     import re
#     line = re.sub(r'\ {2,}'," ",line)
# ```
#
# We update removing multiple space into the *removal_token_length* function

# %%
def removal_token_length(cv_text):
    """
    This function use to remove all the token has length less than 3
    :param
        cv_text: a string of cv
    :result
        a string of token
    """
    cv_text = re.sub(r'\b[a-zA-Z0-9-_]{1,3}\b','',cv_text)
    
    #remove multiple space between words
    cv_text = re.sub(r'\ {2,}'," ",cv_text)
    return cv_text

cv_text = removal_token_length(cv_text)
cv_text
# Out:
# 'curriculum Vitae gowribalan MCSI FCMA Aust CGMA Hons Investment Manager with established investment trackrecord across region spanning listed equities sukuks debt securities honed expertise years portfolio management investment analysis experience includes establishing leading Asset Management Division Ahli Bank SAOG launching mutual fund structuring wealth management products strategizing acquisitions handling initial public offerings IPOs raising investment funds across assetclasses riskthresholds credentials include First Class Honours Degree Applied Accounting Hons member Chartered Institute Securities Investment MCSI fellow Chartered Institute Management Accountants FCMA certified Practising Accountant Aust Chartered Global Management Accountant CGMA average returns generated amounts annual average over past years across listed equities exceeding within fixed income asset class professional EXPERIENCE YEARS 3⅓ Ahli Bank SAOG ahlibank Head Asset Management Reported founding employee division tasked with establishing business vertical banking franchise Achievements built client profile spanning region encompassing Pension Funds Banks Insurance Companies Takaful operators Large Corporates Family offices Individual investors investment Management MENA focused capital market investments Mutual Fund Discretionary Portfolio Management service offerings tailored suit varied risk tolerances investment managers with oversight asset allocation security universe selection rket risk management First market with exclusive service offering focusing Income Debt securities Grew from inception within years demography fixed income debt securities remainder equities investment advisory placement Oman Sovereign Sukuk investment advisory Power Company IPOs acted collecting agent Omantel acted collecting agent Islamic Bank Takaful operator collecting agent Oman first Sharia complaint MENA focused fund issue manager fund manager collecting agent wealth Management Product Development yield Enhancer Series Notes income enhancing asset backed notes fixed term return ahliannuities selfdirected wealth management retirement planning solutions Gulf Retirement Investment Plan GRIP holistic services platform targeting self directed retirement planning wealth management solutions acquisitions gulf Mushroom Products GMPI stake Majan Glass MGCI stake Sweets Oman OSCI stake mail vgowribalan gmail vgowribalan live Mobile 0800 Curriculum Vitae 4¼ Oman National Investment Corporation ONIC Holding SAOG onicholding Portfolio Manager Reported Chief Executive Officer member Management Investment Committee responsible formulating overall investment portfolio management strategy portfolios under purview included proprietary portfolio Insurance subsidiary portfolio Insurance Policy holders funds managed accordance with Capital Market Authority stipulated investment guidelines oversight over portfolio 250Mn which consisted market coverage spanning region Equities Fixed Income Strategic Holdings across financial services sector select Global ETFs returns earned averaged over years alpha average over years Financial Corporation saog FINCORP fincorp Assistant Vice President Reported formulated trading portfolio management strategies discretionary mutual fund assets under management Achievements total portfolio under management 220Mn 85Mn return Mutual funds under management recorded exceptional performance exhibiting volatility impressive risk adjusted returns notching alpha α excess Best Performing funds 2007 Generated realised gains excess proprietary trading portfolio return Since appointment initiated equity research reports following segments banking Oman International Bank SAOG OIBB Cement Oman Cement saog OCOI Steel Jazeera Steel Products SAOG ATMI Telecom Oman Telecommunication saog OTEL Worked lead analyst large contracting engineering company which emerged largest history capital market Sultanate 2007 GECS Associates mghglobal Chief Trader Achievements Since ap ...

# %% [markdown]
# ----
#
#
# The context-dependent and context-independent stop words must be removed from vocab
#
# The following script is a function that removing stopword. The list of stopword is given in the file, named *"stopwords_en.txt"*

# %%
def removal_stop_word(cv_text):
    """
    This function use to remove all the stopwords
    :param 
        cv_text: a string of cv
    :result
        a string of token that has been removed all the stopwords
    """
    
    stopwords = None
    with open('stopwords_en.txt','r') as f:
        stopwords = f.readlines()
    stopwords = [word.strip() for word in stopwords]
    
    tokens = cv_text.split(" ")
    cv_removal_stopword = [word for word in tokens if word not in stopwords ]
    
    return " ".join(cv_removal_stopword)
cv_text = removal_stop_word(cv_text)
cv_text
# Out:
# 'curriculum Vitae gowribalan MCSI FCMA Aust CGMA Hons Investment Manager established investment trackrecord region spanning listed equities sukuks debt securities honed expertise years portfolio management investment analysis experience includes establishing leading Asset Management Division Ahli Bank SAOG launching mutual fund structuring wealth management products strategizing acquisitions handling initial public offerings IPOs raising investment funds assetclasses riskthresholds credentials include First Class Honours Degree Applied Accounting Hons member Chartered Institute Securities Investment MCSI fellow Chartered Institute Management Accountants FCMA certified Practising Accountant Aust Chartered Global Management Accountant CGMA average returns generated amounts annual average past years listed equities exceeding fixed income asset class professional EXPERIENCE YEARS 3⅓ Ahli Bank SAOG ahlibank Head Asset Management Reported founding employee division tasked establishing business vertical banking franchise Achievements built client profile spanning region encompassing Pension Funds Banks Insurance Companies Takaful operators Large Corporates Family offices Individual investors investment Management MENA focused capital market investments Mutual Fund Discretionary Portfolio Management service offerings tailored suit varied risk tolerances investment managers oversight asset allocation security universe selection rket risk management First market exclusive service offering focusing Income Debt securities Grew inception years demography fixed income debt securities remainder equities investment advisory placement Oman Sovereign Sukuk investment advisory Power Company IPOs acted collecting agent Omantel acted collecting agent Islamic Bank Takaful operator collecting agent Oman Sharia complaint MENA focused fund issue manager fund manager collecting agent wealth Management Product Development yield Enhancer Series Notes income enhancing asset backed notes fixed term return ahliannuities selfdirected wealth management retirement planning solutions Gulf Retirement Investment Plan GRIP holistic services platform targeting directed retirement planning wealth management solutions acquisitions gulf Mushroom Products GMPI stake Majan Glass MGCI stake Sweets Oman OSCI stake mail vgowribalan gmail vgowribalan live Mobile 0800 Curriculum Vitae 4¼ Oman National Investment Corporation ONIC Holding SAOG onicholding Portfolio Manager Reported Chief Executive Officer member Management Investment Committee responsible formulating investment portfolio management strategy portfolios purview included proprietary portfolio Insurance subsidiary portfolio Insurance Policy holders funds managed accordance Capital Market Authority stipulated investment guidelines oversight portfolio 250Mn consisted market coverage spanning region Equities Fixed Income Strategic Holdings financial services sector select Global ETFs returns earned averaged years alpha average years Financial Corporation saog FINCORP fincorp Assistant Vice President Reported formulated trading portfolio management strategies discretionary mutual fund assets management Achievements total portfolio management 220Mn 85Mn return Mutual funds management recorded exceptional performance exhibiting volatility impressive risk adjusted returns notching alpha α excess Best Performing funds 2007 Generated realised gains excess proprietary trading portfolio return Since appointment initiated equity research reports segments banking Oman International Bank SAOG OIBB Cement Oman Cement saog OCOI Steel Jazeera Steel Products SAOG ATMI Telecom Oman Telecommunication saog OTEL Worked lead analyst large contracting engineering company emerged largest history capital market Sultanate 2007 GECS Associates mghglobal Chief Trader Achievements Since appointment achieved increased total portfolio management 15Mn increase returns Securities hnbsl Assistant Manager Trading Strategy Reported responsible formul ...

# %% [markdown]
# Rare token (with the threshold set to %2) and context-dependent (with the threshold set to %98) must be removed.
#
# In order to do that, we are going to construct a dictionary of from given cv with the key are unique tokens and the value is the number of time it happens in all documents, but we count 1 for each document or in other word, we use document frequency
#
# E.g:
#
# the word "skill" may occur several times in resume_1 but we count only  one time.
#
# The following is sample of dictionary from unique tokens.
#
# {
#
# ` 'Principled': 1,
#  'calendars': 1,
#  'walkthroughs': 3,
#  'VMware': 2,
#  'submitting': 2,
#  'review': 102,
#  'solution': 5,
#  'xcel': 1,
#  'BLING': 1,
#  .......
# `
#
# }

# %% [markdown]
# Following are two funtions to construct dictionary and remove rare and most frequency

# %%
def construct_dictionary(cvs):
    """
    This function use to construct dictionary of tokens
    :param
          cvs: a list of resume content
    :result
          return a dictionary
    """
    unique_token = list(set(" ".join(cvs).split(" ")))
    dic = dict([(key,0) for key in unique_token])
    for cv in cvs:
        tokens = cv.split(" ")
        tokens = list(set(tokens))
        for token in tokens:
            if token in dic:
                if dic[token] == 0:
                    dic[token] = 1
                else:
                    dic[token] = dic[token] + 1
    dic.pop('')
    return dic
                
    
def removal_rare_and_most_frequency(cvs):
    """
    This function use to remove rare the most frequency token (with threshold set to 98%), 
    :param
        cv_text: a string of cv
    :result
        a string of token that has been removed rare token
    """
    
    
    # construct dictionary of stopword with threshold 2% and 98%
    contents = [cv[1] for cv in cvs]
    dict_cv = construct_dictionary(contents)
    number_of_cv = len(cvs)
    for key in dict_cv:
        dict_cv[key] = dict_cv[key] / number_of_cv
        
    #  create a new stopwords which include the rare tokens and most frequency tokens
    for key in list(dict_cv):
        if dict_cv[key] < 0.98 and dict_cv[key] > 0.02:
            dict_cv.pop(key)
    
    # remove the new stopwords
    new_cvs = []
    for cv in cvs:
        _cv = [c for c in cv[1].split(" ") if c not in dict_cv and c.strip() != '']
        _cv = " ".join(_cv)
        new_cvs.append((cv[0],_cv))
    return new_cvs

# %% [markdown]
# Now we are going to stemm all the token by using PorterStemmer.

# %%
def porter_stemming(cv_text):
    porter = PorterStemmer()
    cv_stem = [porter.stem(word) for word in cv_text.split(" ")]
    return " ".join(cv_stem)

# %% [markdown]
# We have been done almost everything regarding of the pre-processing data.
#
# By now, we can incorporate all the function above to get requirements done.
#
# First of all, we will read txt format cv file, then, we are going to process data by normalizing, extracting tokens, removing stop words,removing token has length less than 3 and stemming by using Porter stemmer.
#
# After pre-processing for each cv, we append data to a variable name cv_text. Finally, we will remove most frequency tokens (with threshold set to 98%), remove rare token (with threshold set to 2%) and finally extract meaningful biagram

# %%
# list of cv tokens without stemming
cvs_collocations = []
# list of cv tokens with stemming
cvs_porter = []

for resume_number in cv_list:
    path_resume = get_path_resume(resume_number)
    resume_content = read_cv_txt(path_resume)
    resume_content = normalized_lower_case(resume_content)
    resume_content = get_tokens(resume_content)
    resume_content = removal_token_length(resume_content)
    resume_content = removal_stop_word(resume_content)
    if len(resume_content) > 0:
        cvs_collocations.append((resume_number,resume_content))
        porter_content = porter_stemming(resume_content)
        cvs_porter.append((resume_number,porter_content))

cvs_collocations = removal_rare_and_most_frequency(cvs_collocations)
cvs_porter = removal_rare_and_most_frequency(cvs_porter)

# %% [markdown]
# At this time, we can go to extract biagram by using BiagramAssocMeasures from *nltk* library.
#
# In this following script above, we extract biagram with PMI measure

# %%
resume_contents = [c[1] for c in cvs_collocations if c[1].strip() != ""]
bigram_measures = nltk.collocations.BigramAssocMeasures()
bigram_finder = nltk.collocations.BigramCollocationFinder.from_words(" ".join(resume_contents).split(" "))
bigram_finder.apply_freq_filter(10)
bigram_finder.apply_word_filter(lambda w: len(w) < 3)
bigram_finder.apply_word_filter(lambda w: w[0].isalpha()!=True and w[1].isalpha() !=True)
top_200_bigrams = bigram_finder.nbest(bigram_measures.pmi, 200) # Top-100 bigrams
top_200_bigrams
# Out:
# [('Goldman', 'Sachs'),
#  ('HONG', 'KONG'),
#  ('Curriculum', 'Vitae'),
#  ('Morgan', 'Stanley'),
#  ('problem', 'solving'),
#  ('Monetary', 'Authority'),
#  ('journal', 'entries'),
#  ('Dean', 'List'),
#  ('Thomson', 'Reuters'),
#  ('Cayman', 'Islands'),
#  ('Date', 'Birth'),
#  ('Ernst', 'Young'),
#  ('sovereign', 'wealth'),
#  ('ADDITIONAL', 'INFORMATION'),
#  ('balance', 'sheet'),
#  ('Available', 'request'),
#  ('Fixed', 'Income'),
#  ('Vice', 'President'),
#  ('CURRICULAR', 'ACTIVITIES'),
#  ('tight', 'deadlines'),
#  ('United', 'Kingdom'),
#  ('United', 'States'),
#  ('phone', 'calls'),
#  ('unit', 'trusts'),
#  ('Case', 'Competition'),
#  ('Expected', 'Salary'),
#  ('Nanyang', 'Technological'),
#  ('pitch', 'books'),
#  ('Credit', 'Suisse'),
#  ('Real', 'Estate'),
#  ('wide', 'range'),
#  ('fixed', 'income'),
#  ('prime', 'brokers'),
#  ('Temasek', 'Polytechnic'),
#  ('real', 'estate'),
#  ('Reporting', 'Standards'),
#  ('written', 'spoken'),
#  ('spoken', 'written'),
#  ('Certified', 'Public'),
#  ('account', 'opening'),
#  ('full', 'spectrum'),
#  ('Class', 'Honours'),
#  ('month', 'notice'),
#  ('First', 'Class'),
#  ('discounted', 'cash'),
#  ('information', 'memorandum'),
#  ('Second', 'Class'),
#  ('Standard', 'Chartered'),
#  ('Level', 'Candidate'),
#  ('Class', 'Honors'),
#  ('Junior', 'College'),
#  ('budget', 'forecast'),
#  ('Public', 'Accountants'),
#  ('service', 'providers'),
#  ('timely', 'manner'),
#  ('Information', 'Technology'),
#  ('PROFESSIONAL', 'QUALIFICATIONS'),
#  ('WORK', 'EXPERIENCE'),
#  ('WORKING', 'EXPERIENCE'),
#  ('worked', 'closely'),
#  ('Deutsche', 'Bank'),
#  ('Asset', 'Value'),
#  ('Word', 'PowerPoint'),
#  ('Hedge', 'Funds'),
#  ('Technical', 'Skills'),
#  ('Bachelor', 'Arts'),
#  ('asset', 'classes'),
#  ('Team', 'Leader'),
#  ('cash', 'flows'),
#  ('HSBC', 'Institutional'),
#  ('corporate', 'actions'),
#  ('Asia', 'Pacific'),
#  ('Email', 'yahoo'),
#  ('Sydney', 'Australia'),
#  ('Work', 'Experience'),
#  ('Cantonese', 'Native'),
#  ('Secondary', 'School'),
#  ('cash', 'flow'),
#  ('Private', 'Equity'),
#  ('Stock', 'Exchange'),
#  ('Southeast', 'Asia'),
#  ('Accountants', 'ACCA'),
#  ('Greater', 'China'),
#  ('Company', 'Secretarial'),
#  ('Association', 'Chartered'),
#  ('policies', 'procedures'),
#  ('Institutional', 'Trust'),
#  ('corporate', 'governance'),
#  ('Excel', 'PowerPoint'),
#  ('Managing', 'Director'),
#  ('month', 'closing'),
#  ('Microsoft', 'Office'),
#  ('Email', 'gmail'),
#  ('presentation', 'materials'),
#  ('SKILLS', 'INTERESTS'),
#  ('Master', 'Science'),
#  ('PROFESSIONAL', 'EXPERIENCE'),
#  ('Certified', 'Accountants'),
#  ('Student', 'Exchange'),
#  ('Summer', 'Intern'),
#  ('Mobile', 'Email'),
#  ('Bachelor', 'Commerce'),
#  ('interpersonal', 'skills'),
#  ('Email', 'hotmail'),
#  ('external', 'parties'),
#  ('Word', 'Excel'),
#  ('Exchange', 'Program'),
#  ('Technological', 'University'),
#  ('Computer', 'Skills'),
#  ('Capital', 'Markets'),
#  ('mail', 'gmail'),
#  ('Institute', 'Certified'),
#  ('Exchange', 'Programme'),
#  ('Proficient', 'Microsoft'),
#  ('Science', 'Technology'),
#  ('Holdings', 'Limited'),
#  ('pension', 'funds'),
#  ('Assistant', 'Vice'),
#  ('variance', 'analysis'),
#  ('ensure', 'smooth'),
#  ('marketing', 'materials'),
#  ('private', 'equity'),
#  ('Citco', 'Fund'),
#  ('administrative', 'support'),
#  ('Institutional', 'Sales'),
#  ('Hong', 'Kong'),
#  ('internal', 'controls'),
#  ('regulatory', 'requirements'),
#  ('Excel', 'Word'),
#  ('fluent', 'English'),
#  ('communication', 'skills'),
#  ('Contact', 'Email'),
#  ('Chartered', 'Certified'),
#  ('English', 'Mandarin'),
#  ('Languages', 'Fluent'),
#  ('Skills', 'Proficient'),
#  ('Chartered', 'Accountants'),
#  ('Fluent', 'English'),
#  ('hedge', 'funds'),
#  ('bank', 'reconciliations'),
#  ('Mandarin', 'Cantonese'),
#  ('Equity', 'Research'),
#  ('UNIVERSITY', 'Bachelor'),
#  ('weekly', 'monthly'),
#  ('City', 'University'),
#  ('Wealth', 'Management'),
#  ('year', 'months'),
#  ('Bachelor', 'Science'),
#  ('High', 'School'),
#  ('Business', 'Administration'),
#  ('Independent', 'Financial'),
#  ('Bachelor', 'Accountancy'),
#  ('external', 'auditors'),
#  ('mutual', 'funds'),
#  ('Accounts', 'Assistant'),
#  ('work', 'pressure'),
#  ('Audit', 'Assurance'),
#  ('Financial', 'Reporting'),
#  ('Senior', 'Associate'),
#  ('Public', 'Accountant'),
#  ('Investment', 'Banking'),
#  ('years', 'experience'),
#  ('Hedge', 'Fund'),
#  ('related', 'matters'),
#  ('Cantonese', 'Fluent'),
#  ('Microsoft', 'Word'),
#  ('team', 'player'),
#  ('monthly', 'basis'),
#  ('company', 'secretarial'),
#  ('Chartered', 'Accountant'),
#  ('International', 'Holdings'),
#  ('Native', 'English'),
#  ('corporate', 'finance'),
#  ('internal', 'control'),
#  ('debt', 'equity'),
#  ('Research', 'Analyst'),
#  ('analytical', 'skills'),
#  ('Asset', 'Management'),
#  ('fund', 'administrators'),
#  ('gmail', 'Mobile'),
#  ('Fund', 'Managers'),
#  ('internal', 'external'),
#  ('accounting', 'standards'),
#  ('School', 'Nanyang'),
#  ('Shanghai', 'China'),
#  ('financial', 'institutions'),
#  ('fund', 'accountants'),
#  ('holding', 'company'),
#  ('potential', 'investors'),
#  ('Languages', 'English'),
#  ('daily', 'basis'),
#  ('team', 'members'),
#  ('Institute', 'Chartered'),
#  ('National', 'University'),
#  ('Microsoft', 'Excel'),
#  ('Fund', 'Accountant'),
#  ('financial', 'statements'),
#  ('Assistant', 'Manager'),
#  ('Trust', 'Company'),
#  ('advisory', 'services')]

# %% [markdown]
# We also can extract biagram by using the *raw frequency* measure and get the number of highest score

# %%
bigram_measures = nltk.collocations.BigramAssocMeasures()
bigram_finder = BigramCollocationFinder.from_words(" ".join(resume_contents).split(" "))
bigram_finder.apply_freq_filter(20) 
bigram_finder.score_ngrams(bigram_measures.raw_freq)
# Out:
# [(('Hong', 'Kong'), 0.0051536830948595656),
#  (('financial', 'statements'), 0.001483836777954425),
#  (('real', 'estate'), 0.0010996290408055115),
#  (('private', 'equity'), 0.0010201377848436672),
#  (('Real', 'Estate'), 0.0008611552729199788),
#  (('Private', 'Equity'), 0.0008479067302596715),
#  (('Microsoft', 'Office'), 0.000834658187599364),
#  (('Financial', 'Services'), 0.0008081611022787493),
#  (('Bachelor', 'Business'), 0.000794912559618442),
#  (('Email', 'gmail'), 0.000794912559618442),
#  (('English', 'Mandarin'), 0.000794912559618442),
#  (('Business', 'Administration'), 0.0007419183889772125),
#  (('hedge', 'funds'), 0.0007154213036565977),
#  (('Asset', 'Management'), 0.0007021727609962904),
#  (('WORK', 'EXPERIENCE'), 0.000649178590355061),
#  (('Investment', 'Banking'), 0.0006359300476947536),
#  (('financial', 'models'), 0.0006226815050344462),
#  (('asset', 'management'), 0.0006094329623741389),
#  (('Fund', 'Services'), 0.0005696873343932167),
#  (('Senior', 'Associate'), 0.0005696873343932167),
#  (('team', 'members'), 0.0005696873343932167),
#  (('Asia', 'Pacific'), 0.0005564387917329094),
#  (('financial', 'reporting'), 0.000543190249072602),
#  (('internal', 'controls'), 0.0005299417064122947),
#  (('Accounting', 'Finance'), 0.0005166931637519873),
#  (('Fund', 'Accountant'), 0.0005166931637519873),
#  (('Fluent', 'English'), 0.00050344462109168),
#  (('Business', 'School'), 0.0004901960784313725),
#  (('Class', 'Honours'), 0.0004769475357710652),
#  (('University', 'Hong'), 0.0004769475357710652),
#  (('fund', 'managers'), 0.0004769475357710652),
#  (('Holdings', 'Limited'), 0.0004636989931107578),
#  (('University', 'Singapore'), 0.0004636989931107578),
#  (('Certified', 'Public'), 0.00045045045045045046),
#  (('Excel', 'PowerPoint'), 0.00045045045045045046),
#  (('PROFESSIONAL', 'EXPERIENCE'), 0.0004372019077901431),
#  (('Technological', 'University'), 0.0004372019077901431),
#  (('University', 'Bachelor'), 0.0004372019077901431),
#  (('Corporate', 'Finance'), 0.00042395336512983573),
#  (('2011', '2012'), 0.00041070482246952837),
#  (('Financial', 'Reporting'), 0.00041070482246952837),
#  (('Mobile', 'Email'), 0.00041070482246952837),
#  (('Vice', 'President'), 0.00041070482246952837),
#  (('Banking', 'Finance'), 0.000397456279809221),
#  (('Nanyang', 'Technological'), 0.000397456279809221),
#  (('Word', 'Excel'), 0.000397456279809221),
#  (('years', 'experience'), 0.000397456279809221),
#  (('2015', 'Present'), 0.0003842077371489136),
#  (('Singapore', 'Singapore'), 0.0003842077371489136),
#  (('cash', 'flow'), 0.0003842077371489136),
#  (('company', 'secretarial'), 0.0003842077371489136),
#  (('financial', 'reports'), 0.0003842077371489136),
#  (('internal', 'control'), 0.0003842077371489136),
#  (('internal', 'external'), 0.0003842077371489136),
#  (('2012', '2014'), 0.00037095919448860623),
#  (('National', 'University'), 0.00037095919448860623),
#  (('Services', 'Singapore'), 0.00037095919448860623),
#  (('Word', 'PowerPoint'), 0.00037095919448860623),
#  (('Kong', 'Institute'), 0.00035771065182829887),
#  (('Work', 'Experience'), 0.00035771065182829887),
#  (('senior', 'management'), 0.00035771065182829887),
#  (('2012', '2013'), 0.0003444621091679915),
#  (('2014', '2015'), 0.0003444621091679915),
#  (('Bachelor', 'Science'), 0.0003444621091679915),
#  (('Junior', 'College'), 0.0003444621091679915),
#  (('hedge', 'fund'), 0.0003444621091679915),
#  (('2016', 'Present'), 0.00033121356650768415),
#  (('Proficient', 'Microsoft'), 0.00033121356650768415),
#  (('financial', 'statement'), 0.00033121356650768415),
#  (('risk', 'management'), 0.00033121356650768415),
#  (('2010', '2011'), 0.0003179650238473768),
#  (('2015', '2015'), 0.0003179650238473768),
#  (('English', 'Chinese'), 0.0003179650238473768),
#  (('Public', 'Accountants'), 0.0003179650238473768),
#  (('Secondary', 'School'), 0.0003179650238473768),
#  (('University', 'London'), 0.0003179650238473768),
#  (('accounting', 'system'), 0.0003179650238473768),
#  (('2013', '2014'), 0.0003047164811870694),
#  (('2014', 'Present'), 0.0003047164811870694),
#  (('Business', 'Development'), 0.0003047164811870694),
#  (('Ernst', 'Young'), 0.0003047164811870694),
#  (('Excel', 'Word'), 0.0003047164811870694),
#  (('Fixed', 'Income'), 0.0003047164811870694),
#  (('corporate', 'actions'), 0.0003047164811870694),
#  (('financial', 'analysis'), 0.0003047164811870694),
#  (('fund', 'administration'), 0.0003047164811870694),
#  (('Financial', 'Analyst'), 0.00029146793852676206),
#  (('Institute', 'Certified'), 0.00029146793852676206),
#  (('Investment', 'Management'), 0.00029146793852676206),
#  (('Reporting', 'Standards'), 0.00029146793852676206),
#  (('Risk', 'Management'), 0.00029146793852676206),
#  (('equity', 'fund'), 0.00029146793852676206),
#  (('fixed', 'income'), 0.00029146793852676206),
#  (('fund', 'accounting'), 0.00029146793852676206),
#  (('listed', 'companies'), 0.00029146793852676206),
#  (('2010', '2010'), 0.0002782193958664547),
#  (('Assistant', 'Manager'), 0.0002782193958664547),
#  (('Company', 'Limited'), 0.0002782193958664547),
#  (('Equity', 'Research'), 0.0002782193958664547),
#  (('Management', 'University'), 0.0002782193958664547),
#  (('audit', 'engagements'), 0.0002782193958664547),
#  (('fund', 'management'), 0.0002782193958664547),
#  (('fund', 'manager'), 0.0002782193958664547),
#  (('English', 'Fluent'), 0.00026497085320614734),
#  (('business', 'development'), 0.00026497085320614734),
#  (('preparation', 'financial'), 0.00026497085320614734),
#  (('project', 'management'), 0.00026497085320614734)]

# %% [markdown]
# We take the biagrams by using PMI measure. Now, let put the biagram and unigram to the file

# %%
bigram_vocab = [bi[0]+" "+bi[1] for bi in top_200_bigrams]
bigram_vocab = sorted(bigram_vocab)
bigram_vocab
# Out:
# ['ADDITIONAL INFORMATION',
#  'Accountants ACCA',
#  'Accounts Assistant',
#  'Asia Pacific',
#  'Asset Management',
#  'Asset Value',
#  'Assistant Manager',
#  'Assistant Vice',
#  'Association Chartered',
#  'Audit Assurance',
#  'Available request',
#  'Bachelor Accountancy',
#  'Bachelor Arts',
#  'Bachelor Commerce',
#  'Bachelor Science',
#  'Business Administration',
#  'CURRICULAR ACTIVITIES',
#  'Cantonese Fluent',
#  'Cantonese Native',
#  'Capital Markets',
#  'Case Competition',
#  'Cayman Islands',
#  'Certified Accountants',
#  'Certified Public',
#  'Chartered Accountant',
#  'Chartered Accountants',
#  'Chartered Certified',
#  'Citco Fund',
#  'City University',
#  'Class Honors',
#  'Class Honours',
#  'Company Secretarial',
#  'Computer Skills',
#  'Contact Email',
#  'Credit Suisse',
#  'Curriculum Vitae',
#  'Date Birth',
#  'Dean List',
#  'Deutsche Bank',
#  'Email gmail',
#  'Email hotmail',
#  'Email yahoo',
#  'English Mandarin',
#  'Equity Research',
#  'Ernst Young',
#  'Excel PowerPoint',
#  'Excel Word',
#  'Exchange Program',
#  'Exchange Programme',
#  'Expected Salary',
#  'Financial Reporting',
#  'First Class',
#  'Fixed Income',
#  'Fluent English',
#  'Fund Accountant',
#  'Fund Managers',
#  'Goldman Sachs',
#  'Greater China',
#  'HONG KONG',
#  'HSBC Institutional',
#  'Hedge Fund',
#  'Hedge Funds',
#  'High School',
#  'Holdings Limited',
#  'Hong Kong',
#  'Independent Financial',
#  'Information Technology',
#  'Institute Certified',
#  'Institute Chartered',
#  'Institutional Sales',
#  'Institutional Trust',
#  'International Holdings',
#  'Investment Banking',
#  'Junior College',
#  'Languages English',
#  'Languages Fluent',
#  'Level Candidate',
#  'Managing Director',
#  'Mandarin Cantonese',
#  'Master Science',
#  'Microsoft Excel',
#  'Microsoft Office',
#  'Microsoft Word',
#  'Mobile Email',
#  'Monetary Authority',
#  'Morgan Stanley',
#  'Nanyang Technological',
#  'National University',
#  'Native English',
#  'PROFESSIONAL EXPERIENCE',
#  'PROFESSIONAL QUALIFICATIONS',
#  'Private Equity',
#  'Proficient Microsoft',
#  'Public Accountant',
#  'Public Accountants',
#  'Real Estate',
#  'Reporting Standards',
#  'Research Analyst',
#  'SKILLS INTERESTS',
#  'School Nanyang',
#  'Science Technology',
#  'Second Class',
#  'Secondary School',
#  'Senior Associate',
#  'Shanghai China',
#  'Skills Proficient',
#  'Southeast Asia',
#  'Standard Chartered',
#  'Stock Exchange',
#  'Student Exchange',
#  'Summer Intern',
#  'Sydney Australia',
#  'Team Leader',
#  'Technical Skills',
#  'Technological University',
#  'Temasek Polytechnic',
#  'Thomson Reuters',
#  'Trust Company',
#  'UNIVERSITY Bachelor',
#  'United Kingdom',
#  'United States',
#  'Vice President',
#  'WORK EXPERIENCE',
#  'WORKING EXPERIENCE',
#  'Wealth Management',
#  'Word Excel',
#  'Word PowerPoint',
#  'Work Experience',
#  'account opening',
#  'accounting standards',
#  'administrative support',
#  'advisory services',
#  'analytical skills',
#  'asset classes',
#  'balance sheet',
#  'bank reconciliations',
#  'budget forecast',
#  'cash flow',
#  'cash flows',
#  'communication skills',
#  'company secretarial',
#  'corporate actions',
#  'corporate finance',
#  'corporate governance',
#  'daily basis',
#  'debt equity',
#  'discounted cash',
#  'ensure smooth',
#  'external auditors',
#  'external parties',
#  'financial institutions',
#  'financial statements',
#  'fixed income',
#  'fluent English',
#  'full spectrum',
#  'fund accountants',
#  'fund administrators',
#  'gmail Mobile',
#  'hedge funds',
#  'holding company',
#  'information memorandum',
#  'internal control',
#  'internal controls',
#  'internal external',
#  'interpersonal skills',
#  'journal entries',
#  'mail gmail',
#  'marketing materials',
#  'month closing',
#  'month notice',
#  'monthly basis',
#  'mutual funds',
#  'pension funds',
#  'phone calls',
#  'pitch books',
#  'policies procedures',
#  'potential investors',
#  'presentation materials',
#  'prime brokers',
#  'private equity',
#  'problem solving',
#  'real estate',
#  'regulatory requirements',
#  'related matters',
#  'service providers',
#  'sovereign wealth',
#  'spoken written',
#  'team members',
#  'team player',
#  'tight deadlines',
#  'timely manner',
#  'unit trusts',
#  'variance analysis',
#  'weekly monthly',
#  'wide range',
#  'work pressure',
#  'worked closely',
#  'written spoken',
#  'year months',
#  'years experience']

# %% [markdown]
# Now, we going to get unigrams, however, instead of using resume contents from cvs_collocations, we are going to get unigrams by using resume contents from cvs_porter

# %%
count_vectorizer = CountVectorizer()
resume_content_porter = " ".join([cv[1] for cv in cvs_porter])
contents_resumes = count_vectorizer.fit_transform([_cvs])
# print(resume_contents.toarray())
unigrams = count_vectorizer.get_feature_names()
for i in range(0,len(unigrams)):
    print(features[i],":",i)
# Out:
# 100m : 0
# 1986 : 1
# 1988 : 2
# 1989 : 3
# 1990 : 4
# 1991 : 5
# 1993 : 6
# 1994 : 7
# 1995 : 8
# 1996 : 9
# 1997 : 10
# 1998 : 11
# 1999 : 12
# 2000 : 13
# 2001 : 14
# 2002 : 15
# 2003 : 16
# 2004 : 17
# 2005 : 18
# 2006 : 19
# 2007 : 20
# 2008 : 21
# 2009 : 22
# 2010 : 23
# 2011 : 24
# 2012 : 25
# 2013 : 26
# 2014 : 27
# 2015 : 28
# 2016 : 29
# 2017 : 30
# 2018 : 31
# 300m : 32
# abil : 33
# abl : 34
# absolut : 35
# academ : 36
# academi : 37
# acca : 38
# accept : 39
# access : 40
# accomplish : 41
# accord : 42
# account : 43
# accrual : 44
# accur : 45
# accuraci : 46
# achiev : 47
# acquir : 48
# acquisit : 49
# act : 50
# action : 51
# activ : 52
# actual : 53
# adapt : 54
# addit : 55
# address : 56
# adept : 57
# adequ : 58
# adequaci : 59
# adher : 60
# adjust : 61
# admin : 62
# administ : 63
# administr : 64
# admiss : 65
# adob : 66
# adopt : 67
# advanc : 68
# advantag : 69
# advent : 70
# advertis : 71
# advic : 72
# advis : 73
# advisor : 74
# advisori : 75
# aerospac : 76
# affair : 77
# affect : 78
# affili : 79
# africa : 80
# age : 81
# agenc : 82
# agenda : 83
# agent : 84
# aggreg : 85
# agre : 86
# agreement : 87
# agricultur : 88
# airport : 89
# allianc : 90
# alloc : 91
# altern : 92
# alumni : 93
# america : 94
# american : 95
# analys : 96
# analysi : 97
# analyst : 98
# analyt : 99
# analyz : 100
# andrew : 101
# angel : 102
# anglochines : 103
# announc : 104
# annual : 105
# annum : 106
# answer : 107
# antimoney : 108
# apac : 109
# apex : 110
# appli : 111
# applic : 112
# appoint : 113
# apprais : 114
# approach : 115
# appropri : 116
# approv : 117
# titl : 1515
# tong : 1516
# took : 1517
# tool : 1518
# topic : 1519
# toronto : 1520
# total : 1521
# touch : 1522
# tourism : 1523
# tower : 1524
# town : 1525
# track : 1526
# trade : 1527
# trader : 1528
# tradit : 1529
# train : 1530
# traine : 1531
# transact : 1532
# transfer : 1533
# transform : 1534
# transit : 1535
# translat : 1536
# transport : 1537
# travel : 1538
# treasur : 1539
# treasuri : 1540
# treatment : 1541
# trek : 1542
# trend : 1543
# tricor : 1544
# trip : 1545
# true : 1546
# trust : 1547
# truste : 1548
# turnaround : 1549
# turnov : 1550
# type : 1551
# under : 1552
# undergradu : 1553
# underli : 1554
# understand : 1555
# understood : 1556
# undertak : 1557
# undertaken : 1558
# underwrit : 1559
# union : 1560
# unit : 1561
# univers : 1562
# unlist : 1563
# unusu : 1564
# upcom : 1565
# updat : 1566
# upgrad : 1567
# upper : 1568
# usag : 1569
# use : 1570
# user : 1571
# util : 1572
# valid : 1573
# valu : 1574
# valuabl : 1575
# valuat : 1576
# valuer : 1577
# varianc : 1578
# varieti : 1579
# vehicl : 1580
# vendor : 1581
# ventur : 1582
# verbal : 1583
# verif : 1584
# verifi : 1585
# vers : 1586
# vessel : 1587
# vice : 1588
# video : 1589
# vietnam : 1590
# view : 1591
# visa : 1592
# visit : 1593
# visual : 1594
# vita : 1595
# vlookup : 1596
# volum : 1597
# volunt : 1598
# voluntari : 1599
# voucher : 1600
# wale : 1601
# walkthrough : 1602
# wall : 1603
# water : 1604
# waterfal : 1605
# weak : 1606
# wealth : 1607
# websit : 1608
# week : 1609
# weekli : 1610
# welfar : 1611
# well : 1612
# western : 1613
# wholesal : 1614
# wide : 1615
# win : 1616
# wind : 1617
# wing : 1618
# winner : 1619
# winter : 1620
# with : 1621
# wong : 1622
# word : 1623
# work : 1624
# workflow : 1625
# workload : 1626
# workshop : 1627
# world : 1628
# worldwid : 1629
# worth : 1630
# write : 1631
# written : 1632
# wrote : 1633
# xbrl : 1634
# yahoo : 1635
# year : 1636
# yearli : 1637
# yield : 1638
# ying : 1639
# york : 1640
# young : 1641
# youth : 1642
# yuen : 1643
# zealand : 1644
# zhang : 1645

# %% [markdown]
# At this time, we are going to write biagrams and unigrams tokens following format, token_string:integer_index

# %%
with open("resume_vocab.txt",'w') as f:
    for i in range(0,len(bigram_vocab)):
        f.write(bigram_vocab[i]+":"+str(i))
        f.write("\n")
    for j in range(0,len(unigrams)):
        f.write(unigrams[j]+":"+str(j))
        f.write("\n")

# %% [markdown]
# Writing the term frequency of each particular resume from given resume file.

# %%
array_dict_resume = []
for cv in cvs_porter:
    dic = {}
    tokens = cv[1].split(" ")
    for token in tokens:
        if token in dic:
            dic[token] = dic[token] + 1
        else:
            dic[token] = 1
    array_dict_resume.append((cv[0],dic))

# %%
file_vocab_vec = open("resume_countVec.txt",'w')
for d in array_dict_resume:
    file = "resume_("+d[0]+"), "
    token_dic = d[1]
    for key in token_dic:
        file += key+":" + str(token_dic[key]) +", "
    file +="\n"
    file_vocab_vec.write(file)
file_vocab_vec.close()
